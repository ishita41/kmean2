# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.cluster import KMeans

# Generate moon-shaped data
x, y = make_moons(n_samples=200, noise=0.10)

# Plot the original data with colors based on labels (y)
plt.scatter(x[:, 0], x[:, 1], c=y)
plt.title("Original Data")
plt.show()

# KMeans Clustering
km = KMeans(n_clusters=2)
km.fit(x)
centers = km.cluster_centers_
labels = km.labels_

# Plot the clustered data with cluster centers
plt.scatter(x[:, 0], x[:, 1], c=labels)
plt.scatter(centers[:, 0], centers[:, 1], color='red')
plt.title("KMeans Clustering with Centers")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# density based spatial clustring of applicationsith noise

# %% [markdown]
# based upon on the idea that a cluster is a high density area surrounded by a low density region
# stands by exploring a small area if density is "good enough

# %%
from sklearn.cluster import DBSCAN

# Assuming 'x' contains your data points
# dbs = DBSCAN(eps=0.2, min_samples=5)  # Uncomment this line if you haven't defined 'x' previously
dbs = DBSCAN(eps=0.214, min_samples=5)
dbs.fit(x)
ypred=dbs.fit_predict(x)
plt.scatter(x[:,0],x[:,1],c=ypred)
plt.show()
